# %% [markdown]
# <a href="https://colab.research.google.com/github/ACoronaGuzman/Metodos/blob/main/Ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import *
import numpy as np
import matplotlib . pyplot as plt
def funcion1(x):
    return np.exp(x) + 2**(-x)+ 2*cos(x)-6
def d1(x):
    return np.exp(x) - (np.log(2)/( 2**(x))) -2*sin(x)

# %%
# Ingreso datos de entrada para los diferentes métodos a trabajar
a = 1
b = 2
l2=[]
l1=[]
# guarda valores iniciales para Newton
pi=1.1
#guarda valores iniciales del error y del número de iteraciones
tol = 0.000001  #float(input("Ingrese el valor de la tolerancia: "))
nmax = 20 #float(input("Ingrese el número máximo de iteraciones: "))
error = 100
e=100
niter = 1
print("# iter  \t\t P  \t\t error")
print("{0} \t\t {1:6.4f}  \t {2:6.4f}".format(i, pi, error ))
# ciclo iterativo
while error > tol and niter <= nmax:
    fa=funcion1(pi)  
    da=d1(pi)
    p = pi - (fa/da)
    error = abs(p - pi)

    pi=p
    l2.append(error)
    niter += 1
    print("{0} \t\t {1:6.6f} \t {2:6.6f}".format(niter, p,error ))

print("La raíz de la función dada en el intervalo [{0:6.4f},{1:6.4f}] es {2:6.7f}".format(a,b,p))
# Out:
# # iter  		 P  		 error
# 16 		 1.1000  	 100.0000
# 2 		 2.905598 	 1.805598
# 3 		 2.314887 	 0.590711
# 4 		 1.965994 	 0.348894
# 5 		 1.843310 	 0.122684
# 6 		 1.829544 	 0.013766
# 7 		 1.829384 	 0.000161
# 8 		 1.829384 	 0.000000
# La raíz de la función dada en el intervalo [1.0000,2.0000] es 1.8293836

# %%
# guarda valores iniciales para secante
p0=1
p1=1.5
#guarda valores iniciales del error y del número de iteraciones
tol = 0.000001  #float(input("Ingrese el valor de la tolerancia: "))
nmax = 20 #float(input("Ingrese el número máximo de iteraciones: "))
error = 100
e=100
i= 1
# Método de  Secante
print("# iter  \t\t P  \t\t error")
print("{0} \t\t {1:6.4f}  \t {2:6.4f}".format(i, pi, error ))

# ciclo iterativo
while e > tol and niter <= nmax:
    fa=funcion1(p0)  
    fb=funcion1(p1)
    pe= p1 - (fb*(p1-p0))/(fb-fa)
    e= abs(p1 - p0)
    p0=p1
    p1=pe
    i += 1
    l1.append(e)
    print("{0} \t\t {1:6.6f} \t {2:6.6f}".format(i, p1,e ))

print("La raíz de la función dada en el intervalo [{0:6.4f},{1:6.4f}] es {2:6.7f}".format(a,b,p))
# Out:
# # iter  		 P  		 error
# 1 		 1.8294  	 100.0000
# 2 		 2.254822 	 0.500000
# 3 		 1.720523 	 0.754822
# 4 		 1.795937 	 0.534299
# 5 		 1.832641 	 0.075414
# 6 		 1.829291 	 0.036704
# 7 		 1.829383 	 0.003350
# 8 		 1.829384 	 0.000092
# 9 		 1.829384 	 0.000000
# La raíz de la función dada en el intervalo [1.0000,2.0000] es 1.8293836

# %%
plt.plot(l1)
plt.plot(l2)
plt.xlabel("iteraciones")
plt.ylabel("error")
plt.show()
